# %%
import mxnet as mx
from mxnet import nd
from mxnet.gluon.model_zoo.vision import resnet18_v1

# %%
net = resnet18_v1(pretrained=True, ctx=mx.gpu())
# Out:
# None
# /usr/local/lib/python3.5/dist-packages/mxnet-0.11.0-py3.5.egg/mxnet/gluon/parameter.py:267: UserWarning: Parameter resnetv17_conv0_weight is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python3.5/dist-packages/mxnet-0.11.0-py3.5.egg/mxnet/gluon/parameter.py:267: UserWarning: Parameter resnetv17_batchnorm0_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python3.5/dist-packages/mxnet-0.11.0-py3.5.egg/mxnet/gluon/parameter.py:267: UserWarning: Parameter resnetv17_batchnorm0_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# ...

# %%
params = net.collect_params().initialize(mx.init.Normal(sigma=1.), ctx=mx.gpu())
# Out:
# /usr/local/lib/python3.5/dist-packages/mxnet-0.11.0-py3.5.egg/mxnet/gluon/parameter.py:267: UserWarning: Parameter resnetv16_conv0_weight is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python3.5/dist-packages/mxnet-0.11.0-py3.5.egg/mxnet/gluon/parameter.py:267: UserWarning: Parameter resnetv16_batchnorm0_gamma is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# /usr/local/lib/python3.5/dist-packages/mxnet-0.11.0-py3.5.egg/mxnet/gluon/parameter.py:267: UserWarning: Parameter resnetv16_batchnorm0_beta is already initialized, ignoring. Set force_reinit=True to re-initialize.
#   "Set force_reinit=True to re-initialize."%self.name)
# ...

# %%
print(pdict.keys())
# Out:
# odict_keys(['resnetv10_conv0_weight', 'resnetv10_batchnorm0_gamma', 'resnetv10_batchnorm0_beta', 'resnetv10_batchnorm0_running_mean', 'resnetv10_batchnorm0_running_var', 'resnetv10_stage1_conv0_weight', 'resnetv10_stage1_batchnorm0_gamma', 'resnetv10_stage1_batchnorm0_beta', 'resnetv10_stage1_batchnorm0_running_mean', 'resnetv10_stage1_batchnorm0_running_var', 'resnetv10_stage1_conv1_weight', 'resnetv10_stage1_batchnorm1_gamma', 'resnetv10_stage1_batchnorm1_beta', 'resnetv10_stage1_batchnorm1_running_mean', 'resnetv10_stage1_batchnorm1_running_var', 'resnetv10_stage1_conv2_weight', 'resnetv10_stage1_batchnorm2_gamma', 'resnetv10_stage1_batchnorm2_beta', 'resnetv10_stage1_batchnorm2_running_mean', 'resnetv10_stage1_batchnorm2_running_var', 'resnetv10_stage1_conv3_weight', 'resnetv10_stage1_batchnorm3_gamma', 'resnetv10_stage1_batchnorm3_beta', 'resnetv10_stage1_batchnorm3_running_mean', 'resnetv10_stage1_batchnorm3_running_var', 'resnetv10_stage2_conv0_weight', 'resnetv10_stage2_batch
# ...
